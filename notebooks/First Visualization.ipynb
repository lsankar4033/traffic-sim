# %% [markdown]
# Enable matplotlib

# %%
# %matplotlib notebook

# %% [markdown]
# Add traffic_sim project dir to path so that we can properly import modules.

# %%
import os
import sys

project_dir = os.path.split(os.getcwd())[0]
if project_dir not in sys.path:
    sys.path.append(project_dir)

# %% [markdown]
# Let's first look at the displacements of cars towards the middle of a large (1000 car) jam.

# %%
import matplotlib.pyplot as plt

from traffic_sim.simulator import simulate, Params

num_cars = 1000
params = Params(num_cars, 1, 0.2, 1.5, 5, 3, -2, 2)
sim_data = simulate(params, 100)

first_car_xs = [xs[0] for xs in sim_data.xs]
first_car_vs = [vs[0] for vs in sim_data.vs]

plt.title('Car displacements')

# Look at the middle of the jam as these are the cars most affected by collisions behind and ahead.
for i in range(490, 510):
    xs = [xs[i] for xs in sim_data.xs]
    plt.plot(xs, label = 'Car {} displacement'.format(i))
# Out:
# <img src="data:image/png;base64,...">

# %% [markdown]
# As can be seen above, there's a natural tendency for cars towards the middle of the jam to exhibit wavy behaviour. Additionally, there seems to be a propagation of the wave along the cars sequentially.
